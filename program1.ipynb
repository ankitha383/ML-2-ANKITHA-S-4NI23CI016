# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("student_data.csv")
df.to_excel("student_data.xlsx",index=False)
df.head(10)
# Out:
#    Student_Id  Age  Gender  StudyHour  Attendance  Marks Result
# 0           1   18  female        2.5        75.0     55   fail
# 1           2   19    male        4.0        85.0     69   pass
# 2           3   18  female        3.5        89.0     75   pass
# 3           4   20    male        5.0        79.0     89   pass
# 4           5   18  female        2.5        75.0     55   fail
# 5           6   19    male        4.0        85.0     69   pass
# 6           7   18  female        3.5        89.0     75   pass
# 7           8   20    male        5.0         NaN     89   pass
# 8           9   18  female        2.5        75.0     55   fail
# 9          10   19    male        4.0        85.0     69   pass

# %%
df.tail(7)
# Out:
#     Student_Id  Age  Gender  StudyHour  Attendance  Marks Result
# 6            7   18  female        3.5        89.0     75   pass
# 7            8   20    male        5.0         NaN     89   pass
# 8            9   18  female        2.5        75.0     55   fail
# 9           10   19    male        4.0        85.0     69   pass
# 10          11   18  female        3.5         NaN     75   pass
# 11          12   20    male        5.0        79.0     89   pass
# 12          13   18  female        2.5        75.0     55   fail

# %%
df.shape
# Out:
# (13, 7)

# %%
df.columns
# Out:
# Index(['Student_Id', 'Age', 'Gender', 'StudyHour', 'Attendance', 'Marks',
#        'Result'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Student_Id      int64
# Age             int64
# Gender         object
# StudyHour     float64
# Attendance    float64
# Marks           int64
# Result         object
# dtype: object

# %%
df['StudyHour']=df['StudyHour'].fillna(df['StudyHour'].mean())
df['Attendance']=df['Attendance'].fillna(df['Attendance'].mean())
df['Marks']=df['Marks'].fillna(df['Marks'].mean())
df=df.round(1)
print("\ndatset after replacing missing value:")
print(df)
# Out:
# datset after replacing missing value:
#     Student_Id  Age  Gender  StudyHour  Attendance  Marks Result
# 0            1   18  female        2.5        75.0     55   fail
# 1            2   19    male        4.0        85.0     69   pass
# 2            3   18  female        3.5        89.0     75   pass
# 3            4   20    male        5.0        79.0     89   pass
# 4            5   18  female        2.5        75.0     55   fail
# 5            6   19    male        4.0        85.0     69   pass
# 6            7   18  female        3.5        89.0     75   pass
# 8            9   18  female        2.5        75.0     55   fail
# 9           10   19    male        4.0        85.0     69   pass
# 11          12   20    male        5.0        79.0     89   pass
# 12          13   18  female        2.5        75.0     55   fail

# %%
df['Marks'].fillna(df['Marks'].median(),inplace=True)
# Out:
# /tmp/ipykernel_2505/1816101993.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Marks'].fillna(df['Marks'].median(),inplace=True)

# %%
df['Gender'].fillna(df['Gender'].mode()[0],inplace=True)

# %%
df.head(13)
# Out:
#     Student_Id  Age  Gender  StudyHour  Attendance  Marks Result
# 0            1   18  female        2.5        75.0     55   fail
# 1            2   19    male        4.0        85.0     69   pass
# 2            3   18  female        3.5        89.0     75   pass
# 3            4   20    male        5.0        79.0     89   pass
# 4            5   18  female        2.5        75.0     55   fail
# 5            6   19    male        4.0        85.0     69   pass
# 6            7   18  female        3.5        89.0     75   pass
# 8            9   18  female        2.5        75.0     55   fail
# 9           10   19    male        4.0        85.0     69   pass
# 11          12   20    male        5.0        79.0     89   pass
# 12          13   18  female        2.5        75.0     55   fail

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.describe()
# Out:
#        Student_Id        Age  StudyHour  Attendance      Marks
# count   11.000000  11.000000  11.000000   11.000000  11.000000
# mean     6.545455  18.636364   3.545455   81.000000  68.636364
# std      4.033947   0.809040   0.960587    5.727128  12.862914
# min      1.000000  18.000000   2.500000   75.000000  55.000000
# 25%      3.500000  18.000000   2.500000   75.000000  55.000000
# 50%      6.000000  18.000000   3.500000   79.000000  69.000000
# 75%      9.500000  19.000000   4.000000   85.000000  75.000000
# max     13.000000  20.000000   5.000000   89.000000  89.000000

# %%
print(df['Marks'].mean())
print(df['Marks'].median())
print(df['Marks'].std())
print(df['Marks'].min())
print(df['Marks'].max())
# Out:
# 68.63636363636364
# 69.0
# 12.862913567871995
# 55
# 89

# %%
plt.hist(df['Marks'],bins=10)
plt.xlabel('Marks')
plt.ylabel('Frequency')
plt.title('distribution of Marks')
plt.show()

# %%
plt.boxplot(df['Marks'])
plt.ylabel("Marks")
plt.title("Box plot of marks")
plt.show()

# %%
corr=df.corr(numeric_only=True)
print(corr)
# Out:
#             Student_Id       Age  StudyHour  Attendance     Marks
# Student_Id    1.000000  0.128134   0.044575   -0.207766  0.027331
# Age           0.128134  1.000000   0.924119    0.086328  0.793202
# StudyHour     0.044575  0.924119   1.000000    0.436252  0.940291
# Attendance   -0.207766  0.086328   0.436252    1.000000  0.477822
# Marks         0.027331  0.793202   0.940291    0.477822  1.000000

# %%
print(df.shape)
print(df.isnull().sum())
print(df.duplicated().sum())
# Out:
# (11, 7)
# Student_Id    0
# Age           0
# Gender        0
# StudyHour     0
# Attendance    0
# Marks         0
# Result        0
# dtype: int64
# 0
